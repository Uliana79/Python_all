# %% [markdown]
# **Задание 1**
#
# Напишите функцию, которая принимает на вход строку и проверяет, является ли она валидным транспортным номером (1 буква, 3 цифры, 2 буквы, 2–3 цифры). Обратите внимание, что не все буквы кириллического алфавита используются в транспортных номерах.
#
# Если номер валиден, то функция должна возвращать отдельно номер и регион.
#
# *Примеры работы программы:*
#
# car_id = 'А222BС96'
#
# Результат: Номер А222BС валиден. Регион: 96.
#
# car_id = 'АБ22ВВ193'
#
# Результат: Номер не валиден.

# %%
import re

def TransportNomer(car_id):
  car_id = re.findall(r"(?P<TrNomer>[АВЕКМНОРСТУХ]\d{3}[АВЕКМНОРСТУХ]{2})(?P<Region>\d{2,3})", car_id)
  if car_id:
    print("Результат: Номер", car_id[0][0], "валиден. Регион:", car_id[0][1])
  else:
    print("Результат: Номер не валиден.")

# %%
TransportNomer('А222ВС96')
# Out:
# Результат: Номер А222ВС валиден. Регион: 96

# %%
TransportNomer('АБ22ВВ193')
# Out:
# Результат: Номер не валиден.

# %% [markdown]
# **Задание 2 (не обязательное)**
#
# Напишите функцию, которая будет удалять все последовательные повторы слов из заданной строки при помощи регулярных выражений.
#
# Пример работы программы:
#
# some_string = 'Напишите функцию функцию, которая будет будет будет будет удалять все все все все последовательные повторы слов из из из из заданной строки строки при помощи регулярных выражений'
#
# Результат:
# Напишите функцию, которая будет удалять все последовательные повторы слов из заданной строки при помощи регулярных выражений.

# %%
def DeletePovtor(some_string):
  new_some_string = re.sub(r'(\w+)\s+\1', r'\1', some_string)
  while (new_some_string!=some_string):
    some_string = new_some_string
    new_some_string = re.sub(r'(\w+)\s+\1', r'\1', new_some_string)
  print('Результат:', new_some_string)

# %%
some_string ="Напишите функцию функцию, которая будет будет будет будет удалять все все все все последовательные повторы слов из из из из заданной строки строки при помощи регулярных выражений"
DeletePovtor(some_string)
# Out:
# Результат: Напишите функцию, которая будет удалять все последовательные повторы слов изаданной строки при помощи регулярных выражений
